# %% [markdown]
# # Skill Assessment 3

# %% [markdown]
# 1. Read in the text of <u>the Hobbit</u>. It is stored in `hobbit.txt` in the `data` folder.

# %%
file = open("../data/hobbit.txt", "r")

# %% [markdown]
# 2. Save the lines of the text file in a list called `lines`, then close the file. Feel free to look at the lines, if you would like.

# %%
lines = file.readlines()

file.close()

# %%
lines
# Out:
# ['####-Chapter I <br>\n',
#  '\n',
#  'An Unexpected Party\n',
#  '\n',
#  'In a hole in the ground there lived a hobbit. Not a nasty, dirty, wet hole, filled with \n',
#  'the ends of worms and an oozy smell, nor yet a dry, bare, sandy hole with nothing \n',
#  'in it to sit down on or to eat: it was a hobbit-hole, and that means comfort. \n',
#  'It  had  a  perfectly  round  door  like  a  porthole,  painted  green,  with  a  shiny \n',
#  'yellow  brass  knob  in  the  exact middle. The  door  opened  on  to  a  tube-shaped hall \n',
#  'like  a  tunnel:  a  very  comfortable  tunnel without  smoke, with  panelled walls,  and \n',
#  'floors  tiled  and  carpeted,  provided with  polished  chairs,  and  lots  and  lots of pegs \n',
#  'for  hats  and  coats - the hobbit was  fond of visitors. The  tunnel wound on  and on, \n',
#  'going  fairly  but  not  quite  straight  into  the  side  of  the  hill  -  The  Hill,  as  all  the \n',
# ...

# %% [markdown]
# 3. You will now start the process of cleaning the text of the file. First remove any line that is just equal to `"\n"`.

# %%
lines = [line for line in lines if line!='\n']

# %%
lines
# Out:
# ['####-Chapter I <br>\n',
#  'An Unexpected Party\n',
#  'In a hole in the ground there lived a hobbit. Not a nasty, dirty, wet hole, filled with \n',
#  'the ends of worms and an oozy smell, nor yet a dry, bare, sandy hole with nothing \n',
#  'in it to sit down on or to eat: it was a hobbit-hole, and that means comfort. \n',
#  'It  had  a  perfectly  round  door  like  a  porthole,  painted  green,  with  a  shiny \n',
#  'yellow  brass  knob  in  the  exact middle. The  door  opened  on  to  a  tube-shaped hall \n',
#  'like  a  tunnel:  a  very  comfortable  tunnel without  smoke, with  panelled walls,  and \n',
#  'floors  tiled  and  carpeted,  provided with  polished  chairs,  and  lots  and  lots of pegs \n',
#  'for  hats  and  coats - the hobbit was  fond of visitors. The  tunnel wound on  and on, \n',
#  'going  fairly  but  not  quite  straight  into  the  side  of  the  hill  -  The  Hill,  as  all  the \n',
# ...

# %% [markdown]
# 4. The text file contains notations for when a new chapter of the book starts. Each of those lines contains the text `"####-Chapter"`. Remove all of these lines from the `list` of lines.

# %%
lines = [line for line in lines if "####-Chapter" not in line]

# %%
lines
# Out:
# ['An Unexpected Party\n',
#  'In a hole in the ground there lived a hobbit. Not a nasty, dirty, wet hole, filled with \n',
#  'the ends of worms and an oozy smell, nor yet a dry, bare, sandy hole with nothing \n',
#  'in it to sit down on or to eat: it was a hobbit-hole, and that means comfort. \n',
#  'It  had  a  perfectly  round  door  like  a  porthole,  painted  green,  with  a  shiny \n',
#  'yellow  brass  knob  in  the  exact middle. The  door  opened  on  to  a  tube-shaped hall \n',
#  'like  a  tunnel:  a  very  comfortable  tunnel without  smoke, with  panelled walls,  and \n',
#  'floors  tiled  and  carpeted,  provided with  polished  chairs,  and  lots  and  lots of pegs \n',
#  'for  hats  and  coats - the hobbit was  fond of visitors. The  tunnel wound on  and on, \n',
#  'going  fairly  but  not  quite  straight  into  the  side  of  the  hill  -  The  Hill,  as  all  the \n',
# ...

# %% [markdown]
# 5. The code below creates a list called `punctuation` which contains the most common punctuation strings. Write a function that takes in a string and `replace`s all of the punctuation in the string with a `" "`. Use that function to remove all punctuation from the lines of the text.

# %%
from string import punctuation

# %%
punctuation = [p for p in punctuation]
punctuation.extend(["“", "”", "...", "’", "—", "…", "»"])

# %%
def remove_punctuation(text):
    for p in punctuation:
        text = text.replace(p, " ")
    return text

# %%
lines = [remove_punctuation(line) for line in lines]

# %%
lines
# Out:
# ['An Unexpected Party\n',
#  'In a hole in the ground there lived a hobbit  Not a nasty  dirty  wet hole  filled with \n',
#  'the ends of worms and an oozy smell  nor yet a dry  bare  sandy hole with nothing \n',
#  'in it to sit down on or to eat  it was a hobbit hole  and that means comfort  \n',
#  'It  had  a  perfectly  round  door  like  a  porthole   painted  green   with  a  shiny \n',
#  'yellow  brass  knob  in  the  exact middle  The  door  opened  on  to  a  tube shaped hall \n',
#  'like  a  tunnel   a  very  comfortable  tunnel without  smoke  with  panelled walls   and \n',
#  'floors  tiled  and  carpeted   provided with  polished  chairs   and  lots  and  lots of pegs \n',
#  'for  hats  and  coats   the hobbit was  fond of visitors  The  tunnel wound on  and on  \n',
#  'going  fairly  but  not  quite  straight  into  the  side  of  the  hill     The  Hill   as  all  the \n',
# ...

# %% [markdown]
# 6. Use `.strip()` to remove the whitespace at the beginning and end of each line of text.

# %%
lines = [line.strip() for line in lines]

# %%
lines
# Out:
# ['An Unexpected Party',
#  'In a hole in the ground there lived a hobbit  Not a nasty  dirty  wet hole  filled with',
#  'the ends of worms and an oozy smell  nor yet a dry  bare  sandy hole with nothing',
#  'in it to sit down on or to eat  it was a hobbit hole  and that means comfort',
#  'It  had  a  perfectly  round  door  like  a  porthole   painted  green   with  a  shiny',
#  'yellow  brass  knob  in  the  exact middle  The  door  opened  on  to  a  tube shaped hall',
#  'like  a  tunnel   a  very  comfortable  tunnel without  smoke  with  panelled walls   and',
#  'floors  tiled  and  carpeted   provided with  polished  chairs   and  lots  and  lots of pegs',
#  'for  hats  and  coats   the hobbit was  fond of visitors  The  tunnel wound on  and on',
#  'going  fairly  but  not  quite  straight  into  the  side  of  the  hill     The  Hill   as  all  the',
#  'people for many miles round called  it   and many little round doors opened out of',
# ...

# %% [markdown]
# 7. Count the unique words, ignoring case, used in the text and store those counts in a dictionary.
#
# <i>Hint: `.split()` may be useful, <a href="https://docs.python.org/3/library/stdtypes.html#str.split">https://docs.python.org/3/library/stdtypes.html#str.split</a></i>.

# %%
word_dict = {}

for line in lines:
    for token in line.split():
        if token.lower() in word_dict.keys():
            word_dict[token.lower()] = word_dict[token.lower()] + 1
        else:
            word_dict[token.lower()] = 1
            
word_dict
# Out:
# {'an': 124,
#  'unexpected': 9,
#  'party': 15,
#  'in': 1473,
#  'a': 1963,
#  'hole': 43,
#  'the': 6103,
#  'ground': 42,
#  'there': 535,
#  'lived': 26,
#  'hobbit': 161,
#  'not': 740,
#  'nasty': 30,
#  'dirty': 3,
#  'wet': 14,
#  'filled': 35,
#  'with': 654,
#  'ends': 4,
#  'of': 2491,
#  'worms': 2,
#  'and': 4512,
#  'oozy': 1,
#  'smell': 23,
#  'nor': 56,
#  'yet': 81,
#  'dry': 14,
#  'bare': 6,
#  'sandy': 1,
#  'nothing': 78,
#  'it': 1234,
#  'to': 2104,
#  'sit': 28,
#  'down': 315,
#  'on': 775,
#  'or': 368,
#  'eat': 30,
#  'was': 1386,
#  'that': 1063,
#  'means': 6,
#  'comfort': 6,
#  'had': 950,
#  'perfectly': 6,
#  'round': 111,
#  'door': 121,
#  'like': 234,
#  'porthole': 1,
#  'painted': 2,
#  'green': 42,
#  'shiny': 1,
#  'yellow': 14,
#  'brass': 4,
#  'knob': 2,
#  'exact': 3,
#  'middle': 20,
#  'opened': 28,
#  'tube': 1,
#  'shaped': 5,
#  'hall': 49,
#  'tunnel': 43,
#  'very': 257,
#  'comfortable': 15,
#  'without': 91,
#  'smoke': 26,
# ...

# %% [markdown]
# 8. Make a `pandas` `DataFrame`containing the information you produced in 7. What are the 25 most used words?

# %%
import pandas as pd

# %%
word_df = pd.DataFrame({'word':word_dict.keys(),
                           'times_used':word_dict.values()}).sort_values('times_used', ascending=False)

# %%
word_df.head(25)
# Out:
#      word  times_used
# 6     the        6103
# 20    and        4512
# 18     of        2491
# 30     to        2104
# 4       a        1963
# 108    he        1907
# 3      in        1473
# 36    was        1386
# 153  they        1367
# 29     it        1234
# 37   that        1063
# 40    had         950
# 131   his         907
# 191     i         843
# 159   you         840
# 33     on         775
# 11    not         740
# 73    for         729
# 115  were         696
# 87     as         696
# 241    at         665
# 88    all         664
# 81    but         657
# 16   with         654
# 297  said         584

# %% [markdown]
# 9. A common step in text analysis (or natural language processing) is removing what are known as <i>stop words</i>. Stop words are commonly used words in a language that do not significantly contribute to the content of the text, for example the word "the". In the `data` folder there is `stopwords.csv` which contains a list of English stop words. Use this list to produce a word count `DataFrame` that does not contain these stop words. Then reexamine the top 25 words.

# %%
stop_df = pd.read_csv("../data/stopwords.csv")

stop = stop_df.word.values

# %%
stop
# Out:
# array(['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you',
#        "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself',
#        'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her',
#        'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them',
#        'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom',
#        'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are',
#        'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had',
#        'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and',
#        'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at',
#        'by', 'for', 'with', 'about', 'against', 'between', 'into',
#        'through', 'during', 'before', 'after', 'above', 'below', 'to',
#        'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under',
#        'again', 'further', 'then', 'once', 'here', 'there', 'when',
# ...

# %%
word_df_no_stop = word_df.loc[~word_df.word.isin(stop)].copy()

# %%
word_df_no_stop.head(25)
# Out:
#           word  times_used
# 297       said         584
# 281      bilbo         554
# 160      could         381
# 97         one         296
# 212    dwarves         292
# 394       came         256
# 877     thorin         251
# 163      would         248
# 44        like         234
# 262       long         228
# 144       time         228
# 758       back         221
# 229       come         210
# 567      great         201
# 265       good         190
# 393    gandalf         187
# 309      still         185
# 614        far         172
# 1146  mountain         172
# 280         go         170
# 185        see         167
# 93      little         167
# 404       went         167
# 515       last         166
# 10      hobbit         161

# %% [markdown]
# 10. Using `matplotlib`'s `barh` function, <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.barh.html">https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.barh.html</a>. Make a horizontal bar chart presenting the top 50 most used words from <u>The Hobbit</u> (not including stop words).

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,12))

words = list(word_df_no_stop.head(50).word.values)
counts = list(word_df_no_stop.head(50).times_used.values)

words.reverse()
counts.reverse()

plt.barh(words,
         counts)

plt.show()

# %% [markdown]
# 11. Using `numpy`'s `.log()` function, plot the log of the rank of the word's usage (e.g. "said" is rank 1, "bilbo" is rank 2, "could" is rank 3", etc.) on the horizontal axis, and the log of the word's total usage on the vertical axis. Plot this as a scatter plot. What you will see is a demonstration of <i>Zipf's Law</i>, which is an observed phenomenon in human language. Zipf's law states that the frequency of a word in a piece of text is inversely proportional to the rank of that word, <a href="https://en.wikipedia.org/wiki/Zipf%27s_law">https://en.wikipedia.org/wiki/Zipf%27s_law</a>.
#
# <i>Note: Ignore ties in word usage when finding the rank.</i>

# %%
import numpy as np

# %%
plt.figsize=(8,6)

plt.scatter(np.log(np.arange(1, len(word_df_no_stop)+1)),
                np.log(word_df_no_stop.times_used))

plt.ylabel("$\log($Word Frequeny$)$", fontsize=11)
plt.xlabel("$\log($Word Rank$)$", fontsize=11)
plt.title("The Hobbit", fontsize=12)

plt.show()

# %% [markdown]
# --------------------------
#
# This notebook was written for the Erd&#337;s Institute C&#337;de Data Science Boot Camp by Matthew Osborne, Ph. D., 2023.
#
# Any potential redistributors must seek and receive permission from Matthew Tyler Osborne, Ph.D. prior to redistribution. Redistribution of the material contained in this repository is conditional on acknowledgement of Matthew Tyler Osborne, Ph.D.'s original authorship and sponsorship of the Erdős Institute as subject to the license (see License.md)
