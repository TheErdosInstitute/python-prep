# %% [markdown]
# # `jupyter notebook`s
#
# This notebook contains problems whose intent is to increase your familiarity with `jupyter notebooks`.
#
# Since the lectures are exclusively in `jupyter notebook`s it is important that you are comfortable working with them.

# %% [markdown]
# ## Basic Problems
#
# 1. Create a `Code` block below this `Markdown` block and execute `2+2`.

# %%
2+2
# Out:
# 4

# %% [markdown]
# 2. Create a `Markdown` block below this `Markdown` block and write a silly sentence.

# %% [markdown]
# "A little consideration, a little thought for others, makes all the difference." -Eeyore

# %% [markdown]
# 3. Copy and paste this `Markdown` block immediately below using the icons in the tool bar above.

# %% [markdown]
# 3. Copy and paste this `Markdown` block immediately below using the icons in the tool bar above.

# %% [markdown]
# 4. Click on the `Kernel` dropdown button above and select `Restart & Clear Output`. What happened to the code chunk you executed in 1. above?

# %% [markdown]
# It should no longer be executed.

# %% [markdown]
# ## More Advanced Problems
#
# 1. Find out how to write mathematical statements in LaTeX within a `Markdown` block.

# %% [markdown]
# If you place something between a pair of $\$$ signs it will be treated like LaTeX. $x+y=z$

# %% [markdown]
# 2. Investigate the differences between #, ##, ###, ####, and ##### (Hint: you'll need to put each on a new line)

# %% [markdown]
# # Biggest Header
#
# ## 2nd Biggest Header
#
# ### 3rd Biggest Header
#
# #### 4th Biggest Header
#
# ##### 5th Biggest Header

# %% [markdown]
# 3. Find out how to highlight something as a piece of code within a `Markdown` block.

# %% [markdown]
# You put it between a pair of \`s, for example, `this is between two tildes`.

# %% [markdown]
# 4. Find out how to insert an image into a `Markdown` chunk. Practice with the file `cat_pic.JPG` in this folder. Is there a way to change the size of the displayed image?

# %% [markdown]
# Use the HTML for an image `<img src="cat_pic.JPEG"></img>`
#
# <img src="cat_pic.JPG" width="30%"></img>

# %% [markdown]
# 5. Hit the `+` button above, then tap your `l` key, what happens to the newly created `Code` block?

# %% [markdown]
# It should turn on line numbers.

# %% [markdown]
# --------------------------
#
# This notebook was written for the Erd&#337;s Institute C&#337;de Data Science Boot Camp by Matthew Osborne, Ph. D., 2023.
#
# Any potential redistributors must seek and receive permission from Matthew Tyler Osborne, Ph.D. prior to redistribution. Redistribution of the material contained in this repository is conditional on acknowledgement of Matthew Tyler Osborne, Ph.D.'s original authorship and sponsorship of the Erdős Institute as subject to the license (see License.md)
